# %% [markdown]
# # Using Jupyter Notebooks
# :label:`sec_jupyter`
#
#
# This section describes how to edit and run the code
# in each section of this book
# using the Jupyter Notebook. Make sure you have
# installed Jupyter and downloaded the
# code as described in
# :ref:`chap_installation`.
# If you want to know more about Jupyter see the excellent tutorial in
# their [documentation](https://jupyter.readthedocs.io/en/latest/).
#
#
# ## Editing and Running the Code Locally
#
# Suppose that the local path of the book's code is `xx/yy/d2l-en/`. Use the shell to change the directory to this path (`cd xx/yy/d2l-en`) and run the command `jupyter notebook`. If your browser does not do this automatically, open http://localhost:8888 and you will see the interface of Jupyter and all the folders containing the code of the book, as shown in :numref:`fig_jupyter00`.
#
# ![The folders containing the code of this book.](https://github.com/d2l-ai/d2l-en-colab/blob/master/img/jupyter00.png?raw=1)
# :width:`600px`
# :label:`fig_jupyter00`
#
#
# You can access the notebook files by clicking on the folder displayed on the webpage.
# They usually have the suffix ".ipynb".
# For the sake of brevity, we create a temporary "test.ipynb" file.
# The content displayed after you click it is
# shown in :numref:`fig_jupyter01`.
# This notebook includes a markdown cell and a code cell. The content in the markdown cell includes "This Is a Title" and "This is text.".
# The code cell contains two lines of Python code.
#
# ![Markdown and code cells in the "text.ipynb" file.](https://github.com/d2l-ai/d2l-en-colab/blob/master/img/jupyter01.png?raw=1)
# :width:`600px`
# :label:`fig_jupyter01`
#
#
# Double click on the markdown cell to enter edit mode.
# Add a new text string "Hello world." at the end of the cell, as shown in :numref:`fig_jupyter02`.
#
# ![Edit the markdown cell.](https://github.com/d2l-ai/d2l-en-colab/blob/master/img/jupyter02.png?raw=1)
# :width:`600px`
# :label:`fig_jupyter02`
#
#
# As demonstrated in :numref:`fig_jupyter03`,
# click "Cell" $\rightarrow$ "Run Cells" in the menu bar to run the edited cell.
#
# ![Run the cell.](https://github.com/d2l-ai/d2l-en-colab/blob/master/img/jupyter03.png?raw=1)
# :width:`600px`
# :label:`fig_jupyter03`
#
# After running, the markdown cell is shown in :numref:`fig_jupyter04`.
#
# ![The markdown cell after running.](https://github.com/d2l-ai/d2l-en-colab/blob/master/img/jupyter04.png?raw=1)
# :width:`600px`
# :label:`fig_jupyter04`
#
#
# Next, click on the code cell. Multiply the elements by 2 after the last line of code, as shown in :numref:`fig_jupyter05`.
#
# ![Edit the code cell.](https://github.com/d2l-ai/d2l-en-colab/blob/master/img/jupyter05.png?raw=1)
# :width:`600px`
# :label:`fig_jupyter05`
#
#
# You can also run the cell with a shortcut ("Ctrl + Enter" by default) and obtain the output result from :numref:`fig_jupyter06`.
#
# ![Run the code cell to obtain the output.](https://github.com/d2l-ai/d2l-en-colab/blob/master/img/jupyter06.png?raw=1)
# :width:`600px`
# :label:`fig_jupyter06`
#
#
# When a notebook contains more cells, we can click "Kernel" $\rightarrow$ "Restart & Run All" in the menu bar to run all the cells in the entire notebook. By clicking "Help" $\rightarrow$ "Edit Keyboard Shortcuts" in the menu bar, you can edit the shortcuts according to your preferences.
#
# ## Advanced Options
#
# Beyond local editing two things are quite important: editing the notebooks in the markdown format and running Jupyter remotely.
# The latter matters when we want to run the code on a faster server.
# The former matters since Jupyter's native ipynb format stores a lot of auxiliary data that is
# irrelevant to the content,
# mostly related to how and where the code is run.
# This is confusing for Git, making
# reviewing contributions very difficult.
# Fortunately there is an alternative---native editing in the markdown format.
#
# ### Markdown Files in Jupyter
#
# If you wish to contribute to the content of this book, you need to modify the
# source file (md file, not ipynb file) on GitHub.
# Using the notedown plugin we
# can modify notebooks in the md format directly in Jupyter.
#
#
# First, install the notedown plugin, run the Jupyter Notebook, and load the plugin:
#
# ```
# pip install d2l-notedown  # You may need to uninstall the original notedown.
# jupyter notebook --NotebookApp.contents_manager_class='notedown.NotedownContentsManager'
# ```
#
# You may also turn on the notedown plugin by default whenever you run the Jupyter Notebook.
# First, generate a Jupyter Notebook configuration file (if it has already been generated, you can skip this step).
#
# ```
# jupyter notebook --generate-config
# ```
#
# Then, add the following line to the end of the Jupyter Notebook configuration file (for Linux or macOS, usually in the path `~/.jupyter/jupyter_notebook_config.py`):
#
# ```
# c.NotebookApp.contents_manager_class = 'notedown.NotedownContentsManager'
# ```
#
# After that, you only need to run the `jupyter notebook` command to turn on the notedown plugin by default.
#
# ### Running Jupyter Notebooks on a Remote Server
#
# Sometimes, you may want to run Jupyter notebooks on a remote server and access it through a browser on your local computer. If Linux or macOS is installed on your local machine (Windows can also support this function through third-party software such as PuTTY), you can use port forwarding:
#
# ```
# ssh myserver -L 8888:localhost:8888
# ```
#
# The above string `myserver` is the address of the remote server.
# Then we can use http://localhost:8888 to access the remote server `myserver` that runs Jupyter notebooks. We will detail on how to run Jupyter notebooks on AWS instances
# later in this appendix.
#
# ### Timing
#
# We can use the `ExecuteTime` plugin to time the execution of each code cell in Jupyter notebooks.
# Use the following commands to install the plugin:
#
# ```
# pip install jupyter_contrib_nbextensions
# jupyter contrib nbextension install --user
# jupyter nbextension enable execute_time/ExecuteTime
# ```
#
# ## Summary
#
# * Using the Jupyter Notebook tool, we can edit, run, and contribute to each section of the book.
# * We can run Jupyter notebooks on remote servers using port forwarding.
#
#
# ## Exercises
#
# 1. Edit and run the code in this book with the Jupyter Notebook on your local machine.
# 1. Edit and run the code in this book with the Jupyter Notebook *remotely* via port forwarding.
# 1. Compare the running time of the operations $\mathbf{A}^\top \mathbf{B}$ and $\mathbf{A} \mathbf{B}$ for two square matrices in $\mathbb{R}^{1024 \times 1024}$. Which one is faster?
#
#
# [Discussions](https://discuss.d2l.ai/t/421)

# %%
# !pip install kaggle --quiet

# Make Kaggle folder and move the token there
# !mkdir ~/.kaggle
# !cp /content/kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# !cp /content/kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# !kaggle datasets download -d orvile/wesad-wearable-stress-affect-detection-dataset

# !unzip wesad-wearable-stress-affect-detection-dataset.zip -d /content/wesad
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists
# Dataset URL: https://www.kaggle.com/datasets/orvile/wesad-wearable-stress-affect-detection-dataset
# License(s): Attribution 4.0 International (CC BY 4.0)
# wesad-wearable-stress-affect-detection-dataset.zip: Skipping, found more recently modified local copy (use --force to force download)
# Archive:  wesad-wearable-stress-affect-detection-dataset.zip
#   inflating: /content/wesad/WESAD/S10/S10.pkl
#   inflating: /content/wesad/WESAD/S10/S10_E4_Data/ACC.csv
#   inflating: /content/wesad/WESAD/S10/S10_E4_Data/BVP.csv
#   inflating: /content/wesad/WESAD/S10/S10_E4_Data/EDA.csv
#   inflating: /content/wesad/WESAD/S10/S10_E4_Data/HR.csv
#   inflating: /content/wesad/WESAD/S10/S10_E4_Data/IBI.csv
#   inflating: /content/wesad/WESAD/S10/S10_E4_Data/TEMP.csv
#   inflating: /content/wesad/WESAD/S10/S10_E4_Data/info.txt
#   inflating: /content/wesad/WESAD/S10/S10_E4_Data/tags.csv
# ...

# %%
# !unzip -o wesad-wearable-stress-affect-detection-dataset.zip -d /content/wesad
# Out:
# Archive:  wesad-wearable-stress-affect-detection-dataset.zip
#   inflating: /content/wesad/WESAD/S10/S10.pkl
#   inflating: /content/wesad/WESAD/S10/S10_E4_Data/ACC.csv
#   inflating: /content/wesad/WESAD/S10/S10_E4_Data/BVP.csv
#   inflating: /content/wesad/WESAD/S10/S10_E4_Data/EDA.csv
#   inflating: /content/wesad/WESAD/S10/S10_E4_Data/HR.csv
#   inflating: /content/wesad/WESAD/S10/S10_E4_Data/IBI.csv
#   inflating: /content/wesad/WESAD/S10/S10_E4_Data/TEMP.csv
#   inflating: /content/wesad/WESAD/S10/S10_E4_Data/info.txt
#   inflating: /content/wesad/WESAD/S10/S10_E4_Data/tags.csv
#   inflating: /content/wesad/WESAD/S10/S10_quest.csv
#   inflating: /content/wesad/WESAD/S10/S10_readme.txt
#   inflating: /content/wesad/WESAD/S10/S10_respiban.txt
#   inflating: /content/wesad/WESAD/S11/S11.pkl
#   inflating: /content/wesad/WESAD/S11/S11_E4_Data/ACC.csv
#   inflating: /content/wesad/WESAD/S11/S11_E4_Data/BVP.csv
#   inflating: /content/wesad/WESAD/S11/S11_E4_Data/EDA.csv
# ...

# %%
import pickle

file_path = "/content/wesad/WESAD/S2/S2.pkl"  # updated path
with open(file_path, "rb") as f:
    data = pickle.load(f, encoding='latin1')

# Check main keys
print(data.keys())

import numpy as np

bvp = np.array(data['signal']['wrist']['BVP'])
print("BVP shape:", bvp.shape)
print("First 10 samples:", bvp[:10])

labels = data['label']
print("Unique labels in this subject:", np.unique(labels))
# Out:
# dict_keys(['signal', 'label', 'subject'])
# BVP shape: (389056, 1)
# First 10 samples: [[-59.37]
#  [-53.42]
#  [-44.4 ]
#  [-33.17]
#  [-20.79]
#  [ -8.33]
#  [  3.4 ]
#  [ 13.85]
#  [ 22.76]
#  [ 30.04]]
# Unique labels in this subject: [0 1 2 3 4 6 7]

# %%
# !pip install neurokit2 --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 708.4/708.4 kB 13.0 MB/s eta 0:00:00

# %%
# -----------------------------
# 1️⃣ Import libraries
# -----------------------------
import os
import pickle
import numpy as np
import pandas as pd
import neurokit2 as nk
import matplotlib.pyplot as plt
from scipy.signal import resample

# -----------------------------
# 2️⃣ Set dataset folder
# -----------------------------
dataset_folder = "/content/wesad/WESAD"

# List all subjects
subjects = sorted([d for d in os.listdir(dataset_folder) if d.startswith("S")])
print("Available subjects:", subjects)

# -----------------------------
# 3️⃣ Load first subject file
# -----------------------------
subject = subjects[0]  # e.g., S2
subject_file = os.path.join(dataset_folder, subject, f"{subject}.pkl")

with open(subject_file, "rb") as f:
    data = pickle.load(f, encoding='latin1')

print("Data keys:", data.keys())
print("Signal keys:", data['signal'].keys())

# -----------------------------
# 4️⃣ Extract wrist BVP signal
# -----------------------------
bvp = np.array(data['signal']['wrist']['BVP']).flatten()  # Flatten to 1D
labels = np.array(data['label']).flatten()
fs = 64  # Wrist BVP sampling rate

print("BVP shape:", bvp.shape)
print("Original labels unique:", np.unique(labels))
# Out:
# Available subjects: ['S10', 'S11', 'S13', 'S14', 'S15', 'S16', 'S17', 'S2', 'S3', 'S4', 'S5', 'S6', 'S7', 'S8', 'S9']
# Data keys: dict_keys(['signal', 'label', 'subject'])
# Signal keys: dict_keys(['chest', 'wrist'])
# BVP shape: (351744,)
# Original labels unique: [0 1 2 3 4 5 6 7]

# %%
import neurokit2 as nk
import pandas as pd
import matplotlib.pyplot as plt

fs = 64  # Wrist BVP sampling rate

# -----------------------------
# 1️⃣ Preprocess BVP signal
# -----------------------------
bvp_clean = nk.signal_filter(bvp, sampling_rate=fs, lowcut=0.5, highcut=5)

# -----------------------------
# 2️⃣ Detect peaks and compute heart rate
# -----------------------------
signals, info = nk.ppg_process(bvp_clean, sampling_rate=fs)
hr = signals["PPG_Rate"]
peaks = info["PPG_Peaks"]

# -----------------------------
# 3️⃣ Compute HRV features
# -----------------------------
hrv_time = nk.hrv_time(peaks, sampling_rate=fs)
hrv_freq = nk.hrv_frequency(peaks, sampling_rate=fs)

print("\nTime-domain HRV features:")
print(hrv_time.head())

print("\nFrequency-domain HRV features:")
print(hrv_freq.head())

# -----------------------------
# 4️⃣ Segment HR by label
# -----------------------------
df = pd.DataFrame({"HR": hr, "Label": labels[:len(hr)]})
label_map = {1:"Baseline", 2:"Stress", 3:"Amusement"}
df["LabelName"] = df["Label"].map(label_map)

# Average HR per label
print("\nAverage HR per state:")
print(df.groupby("LabelName")["HR"].mean())

# -----------------------------
# 5️⃣ Plot HR over time
# -----------------------------
plt.figure(figsize=(15,4))
plt.plot(hr, label="Heart Rate (BPM)")
plt.title("Heart Rate over time")
plt.xlabel("Samples")
plt.ylabel("BPM")
plt.legend()
plt.show()
# Out:
# Time-domain HRV features:
#    HRV_MeanNN    HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  749.675945  493.530762  352.127706  344.593019   244.32641  343.917365
#
#    HRV_SDANN5  HRV_SDNNI5  HRV_RMSSD    HRV_SDSD  ...  HRV_IQRNN  HRV_SDRMSSD  \
# 0  208.654399  361.499221  615.53973  615.581732  ...     218.75     0.801785
#
#    HRV_Prc20NN  HRV_Prc80NN  HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  \
# 0      578.125       843.75   47.19607  65.588757      312.5   24656.25
#
#      HRV_HTI  HRV_TINN
# 0  18.096296       0.0
#
# [1 rows x 25 columns]
#
# Frequency-domain HRV features:
#    HRV_ULF   HRV_VLF    HRV_LF    HRV_HF   HRV_VHF    HRV_TP  HRV_LFHF  \
# 0  0.00006  0.000222  0.000333  0.000122  0.000019  0.000755  2.731899
#
#     HRV_LFn   HRV_HFn  HRV_LnHF
# 0  0.440691  0.161313 -9.013702
#
# Average HR per state:
# LabelName
# Baseline    80.233592
# Name: HR, dtype: float64

# %%
import neurokit2 as nk
import pandas as pd

states = ["Baseline", "Stress", "Amusement"]
label_map = {1:"Baseline", 2:"Stress", 3:"Amusement"}

# Prepare HRV dataframe
hrv_features_list = []

for label_id, state_name in label_map.items():
    # HR for this state
    hr_segment = df[df["Label"]==label_id]["HR"].values

    if len(hr_segment) > 10:  # Ensure enough points
        # Detect peaks in HR segment
        peaks = nk.signal_findpeaks(hr_segment)["Peaks"]

        # Compute time-domain HRV features
        hrv = nk.hrv_time(peaks, sampling_rate=fs)
        hrv["State"] = state_name
        hrv_features_list.append(hrv)

# Combine all states
hrv_df = pd.concat(hrv_features_list, ignore_index=True)

# -----------------------------
# Now aggregate HR and HRV per state
# -----------------------------
agg_features = pd.DataFrame({
    "Mean_HR": [df[df["LabelName"]==s]["HR"].mean() for s in states],
    "SDNN": [hrv_df[hrv_df["State"]==s]["HRV_SDNN"].mean() for s in states],
    "RMSSD": [hrv_df[hrv_df["State"]==s]["HRV_RMSSD"].mean() for s in states]
}, index=states)

print("Aggregated HR & HRV features per state:")
print(agg_features)
# Out:
# Aggregated HR & HRV features per state:
#              Mean_HR         SDNN        RMSSD
# Baseline   80.233592  1837.864991  2212.608272
# Stress           NaN          NaN          NaN
# Amusement        NaN          NaN          NaN

# %%
import matplotlib.pyplot as plt

# -----------------------------
# 1️⃣ Aggregate HR and HRV per state
# -----------------------------
states = ["Baseline", "Stress", "Amusement"]

agg_features = pd.DataFrame({
    "Mean_HR": [df[df["LabelName"]==s]["HR"].mean() for s in states],
    "SDNN": [hrv_df[hrv_df["State"]==s]["HRV_SDNN"].mean() for s in states],
    "RMSSD": [hrv_df[hrv_df["State"]==s]["HRV_RMSSD"].mean() for s in states]
}, index=states)

print("Aggregated HR & HRV features per state:")
print(agg_features)

# -----------------------------
# 2️⃣ Plot bar charts
# -----------------------------
plt.figure(figsize=(15,5))

# Mean HR
plt.subplot(1,3,1)
plt.bar(states, agg_features["Mean_HR"], color=["skyblue","salmon","lightgreen"])
plt.title("Mean Heart Rate (BPM)")
plt.ylabel("BPM")

# SDNN
plt.subplot(1,3,2)
plt.bar(states, agg_features["SDNN"], color=["skyblue","salmon","lightgreen"])
plt.title("SDNN (Time-domain HRV)")
plt.ylabel("ms")

# RMSSD
plt.subplot(1,3,3)
plt.bar(states, agg_features["RMSSD"], color=["skyblue","salmon","lightgreen"])
plt.title("RMSSD (Time-domain HRV)")
plt.ylabel("ms")

plt.tight_layout()
plt.show()
# Out:
# Aggregated HR & HRV features per state:
#              Mean_HR         SDNN        RMSSD
# Baseline   80.233592  1837.864991  2212.608272
# Stress           NaN          NaN          NaN
# Amusement        NaN          NaN          NaN

# %%
features_list = []
window_size = 128
step_size = 64

for start in range(0, len(df_ml)-window_size, step_size):
    end = start + window_size
    hr_window = df_ml["HR"].values[start:end]
    label_window = df_ml["Label"].values[start:end]

    if len(hr_window) < window_size:
        continue

    # Detect peaks
    peaks = nk.signal_findpeaks(hr_window)["Peaks"]

    # Skip if no peaks
    if np.sum(peaks) == 0:
        continue

    # Compute HRV features safely
    try:
        hrv_features = nk.hrv_time(peaks, sampling_rate=fs)
    except Exception as e:
        # Skip this window if hrv_time fails
        continue

    # Skip if HRV returned NaNs
    if np.isnan(hrv_features["HRV_SDNN"].values[0]) or np.isnan(hrv_features["HRV_RMSSD"].values[0]):
        continue

    # Majority label in window
    label = int(np.round(np.mean(label_window)))

    features_list.append({
        "Mean_HR": np.mean(hr_window),
        "SDNN": hrv_features["HRV_SDNN"].values[0],
        "RMSSD": hrv_features["HRV_RMSSD"].values[0],
        "Label": 0 if label==1 else 1  # 0=Baseline, 1=Stress
    })

ml_df = pd.DataFrame(features_list)
print("ML dataset ready, shape:", ml_df.shape)
# Out:
# Streaming output truncated to the last 5000 lines.
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /usr/local/lib/python3.12/dist-packages/neurokit2/hrv/hrv_time.py:166: RuntimeWarning: Mean of empty slice
#   out["MeanNN"] = np.nanmean(rri)
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_nanfunctions_impl.py:2035: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_nanfunctions_impl.py:2035: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /usr/local/lib/python3.12/dist-packages/neurokit2/hrv/hrv_time.py:173: RuntimeWarning: Mean of empty slice
#   out["RMSSD"] = np.sqrt(np.nanmean(diff_rri**2))
# ...

# %%
features_list = []
window_size = 128
step_size = 64

for start in range(0, len(df_ml)-window_size, step_size):
    end = start + window_size
    hr_window = df_ml["HR"].values[start:end]
    label_window = df_ml["Label"].values[start:end]

    if len(hr_window) < window_size:
        continue

    # Detect peaks
    peaks_signal = nk.signal_findpeaks(hr_window)["Peaks"]

    # Ensure at least one actual peak exists
    if np.sum(peaks_signal) == 0:
        continue  # skip this window

    # Compute HRV features safely
    try:
        hrv_features = nk.hrv_time(peaks_signal, sampling_rate=fs)
    except Exception:
        continue  # skip if hrv_time fails

    # Skip if HRV returned NaNs
    if np.isnan(hrv_features["HRV_SDNN"].values[0]) or np.isnan(hrv_features["HRV_RMSSD"].values[0]):
        continue

    # Majority label in window
    label = int(np.round(np.mean(label_window)))

    features_list.append({
        "Mean_HR": np.mean(hr_window),
        "SDNN": hrv_features["HRV_SDNN"].values[0],
        "RMSSD": hrv_features["HRV_RMSSD"].values[0],
        "Label": 0 if label==1 else 1  # 0=Baseline, 1=Stress
    })

ml_df = pd.DataFrame(features_list)
print("ML dataset ready, shape:", ml_df.shape)
# Out:
# Streaming output truncated to the last 5000 lines.
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_nanfunctions_impl.py:2035: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /usr/local/lib/python3.12/dist-packages/neurokit2/hrv/hrv_time.py:166: RuntimeWarning: Mean of empty slice
#   out["MeanNN"] = np.nanmean(rri)
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_nanfunctions_impl.py:2035: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_nanfunctions_impl.py:2035: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# ...

# %%
# ==============================
# 1️⃣ Prepare ML dataset (Stress vs Baseline)
# ==============================
# Keep only Baseline (1) and Stress (2)
df_ml = df[df["Label"].isin([1,2])].copy()
fs = 64  # Sampling rate for wrist BVP

features_list = []
window_size = 128   # samples per window (~2 sec)
step_size = 64      # 50% overlap

for start in range(0, len(df_ml)-window_size, step_size):
    end = start + window_size
    hr_window = df_ml["HR"].values[start:end]
    label_window = df_ml["Label"].values[start:end]

    if len(hr_window) < window_size:
        continue

    # Detect peaks
    peaks_signal = nk.signal_findpeaks(hr_window)["Peaks"]

    # Skip windows with no detected peaks
    if np.sum(peaks_signal) == 0:
        continue

    # Compute HRV safely
    try:
        hrv_features = nk.hrv_time(peaks_signal, sampling_rate=fs)
    except Exception:
        continue

    # Skip if HRV returned NaNs
    if np.isnan(hrv_features["HRV_SDNN"].values[0]) or np.isnan(hrv_features["HRV_RMSSD"].values[0]):
        continue

    # Majority label in window
    label = int(np.round(np.mean(label_window)))

    features_list.append({
        "Mean_HR": np.mean(hr_window),
        "SDNN": hrv_features["HRV_SDNN"].values[0],
        "RMSSD": hrv_features["HRV_RMSSD"].values[0],
        "Label": 0 if label==1 else 1  # 0=Baseline, 1=Stress
    })

ml_df = pd.DataFrame(features_list)
print("ML dataset ready, shape:", ml_df.shape)
print(ml_df.head())

# ==============================
# 2️⃣ Train Random Forest Clas
# Out:
# Streaming output truncated to the last 5000 lines.
# /usr/local/lib/python3.12/dist-packages/neurokit2/hrv/hrv_time.py:166: RuntimeWarning: Mean of empty slice
#   out["MeanNN"] = np.nanmean(rri)
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_nanfunctions_impl.py:2035: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /usr/local/lib/python3.12/dist-packages/neurokit2/hrv/hrv_time.py:166: RuntimeWarning: Mean of empty slice
#   out["MeanNN"] = np.nanmean(rri)
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_nanfunctions_impl.py:2035: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# ...
